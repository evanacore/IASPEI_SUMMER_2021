# %% [markdown]
# For each of the examples you will read a seismic signal from one or more stations. You task is to try and identify:
#
# 1. The signal is an earthquake
#     a. If it is an earthquake, is it a local or teleseismic event?
#     b. Is the signal usable for analysis?
# 2. If not an earthquake what type of signal could it be?
# 3. Start thinking about what you may want to try to do to isolate the signal.
# 4. If a signal is not readily identifiable as an earthquake what other information would be useful for identifying the signal?
#
# Each signal should open in a Matplotlib window. You may use the tools there to zoom into time periods of interest.
# You are encouraged to discuss ideas amoungst yourselves and the instructors.

# %%
import obspy
from obspy import read
import matplotlib.pyplot as plt
import numpy as np

from obspy.clients.fdsn import Client
from obspy import UTCDateTime
from obspy import read

# %% [markdown]
# This waveform was recorded at the Arecibo Observatory seismic station (AOPR) on August 10, 2020.

# %%
st=read('example_AOPR1*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# This second example was recorded at a broadband seismic station in Camp Tracy, UT, USA at 2020-03-18 13:09 (UTC).

# %%
st=read('ex2_CTU*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# The next example if the same station location and time, but this time recorded on a strong motion instrument. The difference between instruments will be discussed later in the course. What is different between these waveforms and the waveforms shown in example 2?

# %%
st=read('ex3_CTU*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# This event was record on a US station EYMN in Ely, Minnesota on 2021-05-28 at 17:13UTC.

# %%
st=read('ex4*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# This example was recorded on 2016-09-09 00:30:01 UTC at the seismic station at Matsushiro, Japan. To remove long period noise this data has been high-pass filtered with a corner of 0.5Hz.

# %%
st=read('../ex5_MAJO*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# This is another example from the same station (MAJO) recorded on 2007-04-01 between 20:30 and 21:30 UTC. How is this different from the previous example?

# %%
st=read('../ex6_*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# This example is from the IU DWPF station in Orlando, Florida, USA recorded on Sept 9-12 2017. What could be generating the observed signal?

# %%
#Files too large for GITHub...We will download the data from IRIS
client = Client("IRIS")
tstart= UTCDateTime("2017-09-09 00:00:00 ")
tend=UTCDateTime("2017-09-12 23:59:59 ")

st = client.get_waveforms('IU','DWPF','*','BH?',tstart,tend,attach_response=True)
# Uncomment this line if you already have the data as a sac file!
#st=read('ex7_*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX

# %% [markdown]
# The final example will revisit the Arecibo Station AOPR. This time the recorded event occurred on 2020-12-01 11:52 UTC. What do you think this is? Hint the station is located near the Arecibo Radio Telescope.

# %%
st=read('ex8_*.sac', debug_headers=True)
# %matplotlib 
st.plot(equal_scale=False)
#dt=st[0].stats.starttime
#st.plot(equal_scale=False, starttime=dt+40, endtime=dt+45)
# Out:
# Using matplotlib backend: MacOSX
